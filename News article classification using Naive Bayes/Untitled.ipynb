# %%
#importing python modeul
import pandas as pd
#importing dataset
news_df = pd.read_csv("uci-news-aggregator.csv", sep = ",")
news_df.CATEGORY.unique()
# Out:
# array(['b', 't', 'e', 'm'], dtype=object)

# %%
import string

news_df['CATEGORY'] = news_df.CATEGORY.map({ 'b': 1, 't': 2, 'e': 3, 'm': 4 })
news_df['TITLE'] = news_df.TITLE.map(
    lambda x: x.lower().translate(str.maketrans('','', string.punctuation))
)
news_df
#news_df.head()
# Out:
#             ID                                              TITLE  \
# 0            1  fed official says weak data caused by weather ...
# 1            2  feds charles plosser sees high bar for change ...
# 2            3  us open stocks fall after fed official hints a...
# 3            4  fed risks falling behind the curve charles plo...
# 4            5   feds plosser nasty weather has curbed job growth
# 5            6   plosser fed may have to accelerate tapering pace
# 6            7            feds plosser taper pace may be too slow
# 7            8  feds plosser expects us unemployment to fall t...
# 8            9  us jobs growth last month hit by weatherfed pr...
# 9           10  ecb unlikely to end sterilisation of smp purch...
# 10          11  ecb unlikely to end sterilization of smp purch...
# 11          12                eus halfbaked bank union could work
# 12          13       europe reaches crunch point on banking union
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(news_df['TITLE'], news_df['CATEGORY'], test_size = 1/3, random_state = 1)

print("Training dataset: ", X_train.shape[0])
print("Test dataset: ", X_test.shape[0])
# Out:
# Training dataset:  281612
# Test dataset:  140807

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vector = CountVectorizer(stop_words = 'english')
training_data = count_vector.fit_transform(X_train)
testing_data = count_vector.transform(X_test)

# %%
from sklearn.naive_bayes import MultinomialNB

naive_bayes = MultinomialNB()
naive_bayes.fit(training_data, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
predictions = naive_bayes.predict(testing_data)
#predictions

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score

print("Accuracy score: ", accuracy_score(y_test, predictions)*100, "%")
print("Recall score: ", recall_score(y_test, predictions, average = 'weighted')*100, "%")
print("Precision score: ", precision_score(y_test, predictions, average = 'weighted')*100, "%")
print("F1 score: ", f1_score(y_test, predictions, average = 'weighted')*100, "%")
# Out:
# Accuracy score:  92.7439686947 %
# Recall score:  92.7439686947 %
# Precision score:  92.751937514 %
# F1 score:  92.7469283612 %

# %%
print(X_test)
# Out:
# 383386                murdochs bid for time warner rejected
# 352807    rescuers close in on 3 trapped honduran miners...
# 106299    johnny depp  johnny depp served with legal pap...
# 256199     apple prepping move into smart home connectivity
# 43325     ripped first look dwayne johnson as brett ratn...
# 111292        women find their place at this passover seder
# 138648                        new canaan religious services
# 343922    europe bank scrutiny proxy guide bnp rises com...
# 284219     how to train your dragon 2′ – what did you think
# 231365                              ebay client info stolen
# 148873    valeant ceo breaks the mold in building drug e...
# 350775                   beyonce pharrell win at bet awards
# 58401              scandal recap youre nothing but the help
# 194799    video of the day see seth rogen and zac efron ...
# 105444           marquez grabs pole for americas grand prix
# 190645              some mangos sold in new jersey recalled
# ...

# %%
#Sample input: 76472, 91589, 56371, 57337, 49798,43325,87389,58401
s = input("Enter the serial number of title: ")
sl = int(s)
print('Title: ', X_test[sl])
#print(predictions[sl])
if(predictions[sl] == 1):print("Category: Bussiness")
elif(predictions[sl] == 2):print("Category: Technology")
elif(predictions[sl] == 3):print("Category: Entertainment")
elif(predictions[sl] == 4):print("Category: Health")
# Out:
# Enter the serial number of title: 76472
# Title:  ag markets proved quite volatile monday
# Category: Health
